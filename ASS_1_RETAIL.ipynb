# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Question 1

# %%
Customer = pd.read_csv(r"C:\Users\MAGICPIN\Desktop\p\assign\Customer.csv")
Customer.head(5)
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
Transactions = pd.read_csv(r"C:\Users\MAGICPIN\Desktop\p\assign\Transactions.csv")
Transactions.head(5)
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
prod_cat_info = pd.read_csv(r"C:\Users\MAGICPIN\Desktop\p\assign\prod_cat_info.csv")
prod_cat_info.head(3)
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids

# %%
Customer_Final0 = pd.merge(left = Customer , right = Transactions , how = 'inner', left_on = 'customer_Id' , right_on = 'cust_id' )
Customer_Final0.head(5)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       268408  02-01-1970      M        4.0     16197868036   268408
# 2       268408  02-01-1970      M        4.0     16197868036   268408
# 3       268408  02-01-1970      M        4.0     28810141075   268408
# 4       268408  02-01-1970      M        4.0     64633435931   268408
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187   98.175   1033.175
# 1  16-12-2013                 1              4   -5  -210  110.250  -1160.250
# 2  12-12-2013                 1              4    5   210  110.250   1160.250
# 3  02-09-2013                10              6    2   813  170.730   1796.730
# 4  06-05-2013                 4              2    3   312   98.280   1034.280
#
#        Store_type
# 0        TeleShop
# 1  Flagship store
# ...

# %%
Customer_Final = pd.merge(left = Customer_Final0 , right = prod_cat_info , how = 'inner', left_on = 'prod_cat_code' , right_on = 'prod_cat_code' )
Customer_Final.head(5)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       268408  02-01-1970      M        4.0     87243835584   268408
# 2       268408  02-01-1970      M        4.0     87243835584   268408
# 3       268408  02-01-1970      M        4.0     87243835584   268408
# 4       268408  02-01-1970      M        4.0     87243835584   268408
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate     Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187  98.175   1033.175
# 1  13-01-2014                 7              5    5   187  98.175   1033.175
# 2  13-01-2014                 7              5    5   187  98.175   1033.175
# 3  13-01-2014                 7              5    5   187  98.175   1033.175
# 4  13-01-2014                 7              5    5   187  98.175   1033.175
#
#   Store_type prod_cat  prod_sub_cat_code  prod_subcat
# ...

# %% [markdown]
# ## Question -2

# %% [markdown]
# ### a. Get the column names and their corresponding data types

# %%
Customer_Final.dtypes
# Out:
# customer_Id            int64
# DOB                   object
# Gender                object
# city_code            float64
# transaction_id         int64
# cust_id                int64
# tran_date             object
# prod_subcat_code       int64
# prod_cat_code          int64
# Qty                    int64
# Rate                   int64
# Tax                  float64
# total_amt            float64
# Store_type            object
# prod_cat              object
# prod_sub_cat_code      int64
# prod_subcat           object
# dtype: object

# %% [markdown]
# ### b. Top/Bottom 10 observations

# %%
Customer_Final.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       268408  02-01-1970      M        4.0     87243835584   268408
# 2       268408  02-01-1970      M        4.0     87243835584   268408
# 3       268408  02-01-1970      M        4.0     87243835584   268408
# 4       268408  02-01-1970      M        4.0     87243835584   268408
# 5       268408  02-01-1970      M        4.0     87243835584   268408
# 6       268159  08-01-1970      F        8.0     65867401816   268159
# 7       268159  08-01-1970      F        8.0     65867401816   268159
# 8       268159  08-01-1970      F        8.0     65867401816   268159
# 9       268159  08-01-1970      F        8.0     65867401816   268159
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187   98.175   1033.175
# ...

# %%
Customer_Final.tail(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 99283       274618  09-12-1992      F        7.0     98631113719   274618
# 99284       268097  15-12-1992      F        7.0     71286190189   268097
# 99285       268097  15-12-1992      F        7.0     71286190189   268097
# 99286       268097  15-12-1992      F        7.0     71286190189   268097
# 99287       271772  17-12-1992      M        2.0     10440850091   271772
# 99288       271772  17-12-1992      M        2.0     10440850091   271772
# 99289       271772  17-12-1992      M        2.0     10440850091   271772
# 99290       269626  27-12-1992      F        5.0     94134051896   269626
# 99291       269626  27-12-1992      F        5.0     94134051896   269626
# 99292       269626  27-12-1992      F        5.0     94134051896   269626
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate     Tax  \
# 99283  19-04-2013                 3              1    2   721  151.41
# ...

# %% [markdown]
# ### c. “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
Customer_Final.describe()
# Out:
#          customer_Id     city_code  transaction_id        cust_id  \
# count   99293.000000  99257.000000    9.929300e+04   99293.000000
# mean   271030.010635      5.467221    5.007320e+10  271030.010635
# std      2429.333624      2.859343    2.899361e+10    2429.333624
# min    266783.000000      1.000000    3.268991e+06  266783.000000
# 25%    268956.000000      3.000000    2.492150e+10  268956.000000
# 50%    270982.000000      5.000000    5.011083e+10  270982.000000
# 75%    273120.000000      8.000000    7.528121e+10  273120.000000
# max    275265.000000     10.000000    9.998755e+10  275265.000000
#
#        prod_subcat_code  prod_cat_code           Qty          Rate  \
# count      99293.000000   99293.000000  99293.000000  99293.000000
# mean           6.796894       4.003243      2.438017    637.919884
# std            3.609439       1.563991      2.260726    621.576326
# min            1.000000       1.000000     -5.000000  -1499.000000
# ...

# %% [markdown]
# ### d. Frequency tables for all the categorical variables

# %%
Customer_Final.loc[:,Customer_Final.dtypes=="object"].describe()
# Out:
#                DOB Gender   tran_date Store_type prod_cat prod_subcat
# count        99293  99253       99293      99293    99293       99293
# unique        3987      2        1129          4        6          18
# top     27-12-1988      M  25-08-2012     e-Shop    Books        Mens
# freq           156  51051         153      40185    36414        7957

# %% [markdown]
# ## 3. Generate histograms for all continuous variables and frequency bars for categorical variables.

# %%
hist = Customer_Final.loc[:,['prod_subcat_code','prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt']]

# %%
hist.columns
# Out:
# Index(['prod_subcat_code', 'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt'], dtype='object')

# %%
for i in hist.columns:
    hist[i].plot(kind='hist')
    plt.title(i)
    plt.show()

# %% [markdown]
# ### Bar chart of categorical variable

# %% [markdown]
# ### Gender

# %%
Customer_Final['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Store_type

# %%
Customer_Final['Store_type'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Product category

# %%
Customer_Final['prod_cat'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### product sub category

# %%
Customer_Final['prod_subcat'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Calculate the following information using the merged dataset :
# ### a. Time period of the available transaction data

# %%
Customer_Final.sort_values(by="tran_date")
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 79063       268571  25-05-1982      F        2.0     66067413087   268571
# 92875       271275  01-07-1976      M        8.0     78865860112   271275
# 90737       268282  22-12-1970      F        1.0     57039573748   268282
# 90738       268282  22-12-1970      F        1.0     57039573748   268282
# 90739       268282  22-12-1970      F        1.0     57039573748   268282
# ...            ...         ...    ...        ...             ...      ...
# 38460       273857  05-07-1981      F        6.0     65594255012   273857
# 35584       274052  13-07-1992      F        5.0     55120134998   274052
# 35583       274052  13-07-1992      F        5.0     55120134998   274052
# 90437       273541  01-02-1970      M        4.0     25511948871   273541
# 84965       275194  18-11-1987      M       10.0     87937803238   275194
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
min_date = Customer_Final["tran_date"].min()
min_date
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
max_date = Customer_Final["tran_date"].max()
max_date
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
import datetime
from datetime import datetime

def differ_days(date1, date2):
    a = date1
    b = date2
    return (a-b).days
print()
print(differ_days((datetime(2014,12,2,0,0,0)), datetime(2011,1,2 ,0,0,0)))
print()
# Out:
# 1430

# %% [markdown]
# ### b. Count of transactions where the total amount of transaction was negative

# %%
negative_transaction = Customer_Final.loc[Customer_Final["total_amt"] < 0,"transaction_id"].count()

# %%
print("Count of transactions where the total amount of transaction was negative is",negative_transaction)
# Out:
# Count of transactions where the total amount of transaction was negative is 9294

# %% [markdown]
# ## 5. Analyze which product categories are more popular among females vs male customers.

# %%
Customer_Final.head(3)
Customer_Final[['prod_cat', 'Gender', 'Qty']].groupby(['Gender', 'prod_cat']).sum()
# Out:
#                            Qty
# Gender prod_cat
# F      Bags               4724
#        Books             42420
#        Clothing          10275
#        Electronics       29160
#        Footwear          11148
#        Home and kitchen  19580
# M      Bags               4692
#        Books             45522
#        Clothing          11244
#        Electronics       32380
#        Footwear          10665
#        Home and kitchen  20164

# %% [markdown]
# ## 6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
df1 = Customer_Final[['city_code' , 'customer_Id'] ].groupby('city_code').count().sort_values('customer_Id',  ascending=False )
df1.head(5)
# Out:
#            customer_Id
# city_code
# 4.0              10571
# 3.0              10467
# 7.0              10258
# 5.0              10116
# 10.0              9976

# %%
df1['percent'] = (df1['customer_Id']/df1['customer_Id'].sum())*100
df1.round(3)
# Out:
#            customer_Id  percent
# city_code
# 4.0              10571   10.650
# 3.0              10467   10.545
# 7.0              10258   10.335
# 5.0              10116   10.192
# 10.0              9976   10.051
# 8.0               9965   10.040
# 2.0               9843    9.917
# 1.0               9717    9.790
# 9.0               9214    9.283
# 6.0               9130    9.198

# %% [markdown]
# ## 7. Which store type sells the maximum products by value and by quantity?

# %%
df2 = Customer_Final[['Store_type', 'total_amt',"Qty"]].groupby(['Store_type', 'total_amt','Qty']).sum().sort_values('total_amt',  ascending=False )
df2.head(3)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(e-Shop, 8287.5, 5), (TeleShop, 8287.5, 5), (MBR, 8287.5, 5)]

# %% [markdown]
# ## 8. What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
df3 = Customer_Final[(Customer_Final['Store_type'] == 'Flagship store') & ((Customer_Final['prod_cat']== 'Electronics') | (Customer_Final['prod_cat']== 'Clothing'))]
df3.head(3)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 65953       270181  10-01-1970      F        2.0     47260895038   270181
# 65954       270181  10-01-1970      F        2.0     47260895038   270181
# 65955       270181  10-01-1970      F        2.0     47260895038   270181
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate     Tax  \
# 65953  18-03-2011                 8              3    1  1012  106.26
# 65954  18-03-2011                 8              3    1  1012  106.26
# 65955  18-03-2011                 8              3    1  1012  106.26
#
#        total_amt      Store_type     prod_cat  prod_sub_cat_code  \
# 65953    1118.26  Flagship store  Electronics                  4
# 65954    1118.26  Flagship store  Electronics                  5
# 65955    1118.26  Flagship store  Electronics                  8
#
#                prod_subcat
# 65953              Mobiles
# 65954            Computers
# 65955  Personal Appliances

# %%
df3[['prod_cat','total_amt']] .groupby('prod_cat').sum()
# Out:
#                total_amt
# prod_cat
# Clothing      3583269.69
# Electronics  11075680.20

# %% [markdown]
# ## 9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
df4 =Customer_Final[(Customer_Final['Gender'] == 'M') & ( Customer_Final['prod_cat']== 'Electronics' )]
df4[['Gender','prod_cat','total_amt']].groupby(['Gender', 'prod_cat']).sum( )
# Out:
#                        total_amt
# Gender prod_cat
# M      Electronics  2.851555e+07

# %% [markdown]
# ## 10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
x = Customer_Final[Customer_Final["total_amt"] > 0]
x.head(3)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       268408  02-01-1970      M        4.0     87243835584   268408
# 2       268408  02-01-1970      M        4.0     87243835584   268408
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate     Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187  98.175   1033.175
# 1  13-01-2014                 7              5    5   187  98.175   1033.175
# 2  13-01-2014                 7              5    5   187  98.175   1033.175
#
#   Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 0   TeleShop    Books                  7      Fiction
# 1   TeleShop    Books                 12     Academic
# 2   TeleShop    Books                 10  Non-Fiction

# %%
unique_trans = x.groupby(['customer_Id','prod_cat','prod_subcat'])['transaction_id'].count().reset_index()

# %%
unique_trans.head(3)
# Out:
#    customer_Id prod_cat prod_subcat  transaction_id
# 0       266783    Books    Academic               1
# 1       266783    Books    Children               1
# 2       266783    Books      Comics               1

# %%
# now finding the customers which have unique transactions greater than 10
unique_trans_count = unique_trans.groupby('customer_Id')['transaction_id'].count().reset_index()
unique_trans_count
# Out:
#       customer_Id  transaction_id
# 0          266783              12
# 1          266784              11
# 2          266785              15
# 3          266788              11
# 4          266794              19
# ...           ...             ...
# 5501       275257              18
# 5502       275261               8
# 5503       275262               8
# 5504       275264              10
# 5505       275265              12
#
# [5506 rows x 2 columns]

# %%
unique_trans_count[unique_trans_count['transaction_id'] > 10]
# Out:
#       customer_Id  transaction_id
# 0          266783              12
# 1          266784              11
# 2          266785              15
# 3          266788              11
# 4          266794              19
# ...           ...             ...
# 5496       275249              11
# 5497       275250              11
# 5499       275252              19
# 5501       275257              18
# 5505       275265              12
#
# [3214 rows x 2 columns]

# %% [markdown]
# ## 11. For all customers aged between 25 - 35, find out:
# ### a. What was the total amount spent for “Electronics” and “Books” product categories?

# %%
Customer_Final.head(3)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       268408  02-01-1970      M        4.0     87243835584   268408
# 2       268408  02-01-1970      M        4.0     87243835584   268408
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate     Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187  98.175   1033.175
# 1  13-01-2014                 7              5    5   187  98.175   1033.175
# 2  13-01-2014                 7              5    5   187  98.175   1033.175
#
#   Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 0   TeleShop    Books                  7      Fiction
# 1   TeleShop    Books                 12     Academic
# 2   TeleShop    Books                 10  Non-Fiction

# %%
curr_year = pd.to_datetime('today').year
dob_year = pd.DatetimeIndex(Customer_Final['DOB']).year          #extract year from DOB
x = dob_year-100                                               # for the years which belongs to 60's
v = curr_year - x
y = curr_year - dob_year
Customer_Final['age'] = (np.where(dob_year > curr_year,v,y))
Customer_Final
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408  02-01-1970      M        4.0     87243835584   268408
# 1           268408  02-01-1970      M        4.0     87243835584   268408
# 2           268408  02-01-1970      M        4.0     87243835584   268408
# 3           268408  02-01-1970      M        4.0     87243835584   268408
# 4           268408  02-01-1970      M        4.0     87243835584   268408
# ...            ...         ...    ...        ...             ...      ...
# 99288       271772  17-12-1992      M        2.0     10440850091   271772
# 99289       271772  17-12-1992      M        2.0     10440850091   271772
# 99290       269626  27-12-1992      F        5.0     94134051896   269626
# 99291       269626  27-12-1992      F        5.0     94134051896   269626
# 99292       269626  27-12-1992      F        5.0     94134051896   269626
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
total = Customer_Final.loc[((Customer_Final.age >25) & (Customer_Final.age <35)) & ((Customer_Final.prod_cat=='Books') | (Customer_Final.prod_cat=='Electronics'))]['total_amt'].sum()
print('Total amount earned',total)
# Out:
# Total amount earned 27367446.599999998

# %% [markdown]
# ### b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
Customer_Final['tran_date'] = pd.to_datetime(Customer_Final['tran_date'])

t_date = Customer_Final[(Customer_Final['tran_date'] > '2014-01-01') & (Customer_Final['tran_date'] < '2014-03-01')]
total_amount = t_date.total_amt.sum()
print('Total amount spent by the customer - ',total_amount)
# Out:
# Total amount spent by the customer -  5591225.965
